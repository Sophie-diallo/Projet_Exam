# %%
import pandas as pd
df = pd.read_csv("Doc.csv")
df
# Out:
#                      Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                        Prénom         Nom    Moyenne       Age
# 1                         ASTOU        Dime         18         25
# 2                           Awa       Dione         18         18
# 3                          Bour       Gueye         18         21
# 4                       Marieme       Gueye         17         23
# 5                 Fatou Binetou        Fall         16         18
# 6            Amadou mactar diop       Badji         16         19
# 7                    Fatou Kiné       DRAME         16         24
# 8                         Khady        Gaye         16         18
# 9                       Mamadou       Ndour         16         18
# 10               Melanie Ndella       Faye          16         19
# 11                          Amy        Deme         16         19
# 12              Seynabou Ngoma         Seck         16         22
# ...

# %%
import pandas as pd
df = pd.read_csv("Doc.csv",nrows=39)
df
# Out:
#                      Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                        Prénom         Nom    Moyenne       Age
# 1                         ASTOU        Dime         18         25
# 2                           Awa       Dione         18         18
# 3                          Bour       Gueye         18         21
# 4                       Marieme       Gueye         17         23
# 5                 Fatou Binetou        Fall         16         18
# 6            Amadou mactar diop       Badji         16         19
# 7                    Fatou Kiné       DRAME         16         24
# 8                         Khady        Gaye         16         18
# 9                       Mamadou       Ndour         16         18
# 10               Melanie Ndella       Faye          16         19
# 11                          Amy        Deme         16         19
# 12              Seynabou Ngoma         Seck         16         22
# ...

# %%
import pandas as pd
df = pd.read_csv("Doc.csv", na_values=('')"18","19","20"])
df
# Out:
#                      Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                        Prénom         Nom    Moyenne       Age
# 1                         ASTOU        Dime        NaN         25
# 2                           Awa       Dione        NaN        NaN
# 3                          Bour       Gueye        NaN         21
# 4                       Marieme       Gueye         17         23
# 5                 Fatou Binetou        Fall         16        NaN
# 6            Amadou mactar diop       Badji         16        NaN
# 7                    Fatou Kiné       DRAME         16         24
# 8                         Khady        Gaye         16        NaN
# 9                       Mamadou       Ndour         16        NaN
# 10               Melanie Ndella       Faye          16        NaN
# 11                          Amy        Deme         16        NaN
# 12              Seynabou Ngoma         Seck         16         22
# ...

# %%
df.columns
# Out:
# Index([',Unnamed: 0,Unnamed: 1,Unnamed: 2,Unnamed: 3,Unnamed: 4,Unnamed: 5,Unnamed: 6'], dtype='object')

# %%
import pandas as pd
df = pd.read_csv("Doc.csv")
df
